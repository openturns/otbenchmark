# %%
import openturns as ot
import otbenchmark as otb
import pandas as pd
import numpy as np

# %%
p = otb.OTReliabilityAlgorithmBenchmark()
List_RP = p.problemslist
np.size(List_RP)
# Out:
# 26

# %%
N = 10 ** 9

# %%
N = np.size(List_RP)
model_names = [List_RP[i].getName() for i in range(N)]
metrics = ["Probabilité estimée", "Nombre d'appels à la fonction d'état limite"]
results = np.zeros((len(model_names), len(metrics)))

for i in range(len(model_names)):
    r = otb.OTReliabilityAlgorithmBenchmark.MonteCarloSampling(List_RP[i], maximumOuterSampling=10000000,
                                                                   coefficientOfVariation=0.1, blockSize=1)
    results[i][0] = np.format_float_scientific(r[0])
    results[i][1] = r[3]
        

df = pd.DataFrame(results, index = model_names, columns=metrics)
df
# Out:
# Problem RP8 Number of function calls = 136181 , Pf = 0.00073 , 95.0 % confidence interval :[0.00059,0.00088]
# Problem RP14 Number of function calls = 144030 , Pf = 0.00069 , 95.0 % confidence interval :[0.00056,0.00083]
# Problem RP22 Number of function calls = 30415 , Pf = 0.00329 , 95.0 % confidence interval :[0.00264,0.00393]
# Problem RP24 Number of function calls = 39295 , Pf = 0.00254 , 95.0 % confidence interval :[0.00205,0.00304]
# Problem RP25 Number of function calls = 2297564 , Pf = 0.00004 , 95.0 % confidence interval :[0.00003,0.00005]
# Problem RP28 Number of function calls = 10000000 , Pf = 0.00000 , 95.0 % confidence interval :[-0.00000,0.00000]
# Problem RP31 Number of function calls = 31322 , Pf = 0.00319 , 95.0 % confidence interval :[0.00257,0.00382]
# Problem RP33 Number of function calls = 36188 , Pf = 0.00276 , 95.0 % confidence interval :[0.00222,0.00330]
# Problem RP35 Number of function calls = 33605 , Pf = 0.00298 , 95.0 % confidence interval :[0.00239,0.00356]
# Problem RP38 Number of function calls = 12418 , Pf = 0.00805 , 95.0 % confidence interval :[0.00648,0.00962]
# Problem RP53 Number of function calls = 2924 , Pf = 0.03317 , 95.0 % confidence interval :[0.02668,0.03967]
# Problem RP55 Number of function calls = 81 , Pf = 0.55556 , 95.0 % confidence interval :[0.44734,0.66377]
# Problem RP54 Number of function calls = 94118 , Pf = 0.00106 , 95.0 % confidence interval :[0.00085,0.00127]
# Problem RP57 Number of function calls = 3559 , Pf = 0.02754 , 95.0 % confidence interval :[0.02216,0.03291]
# Problem RP75 Number of function calls = 9587 , Pf = 0.01033 , 95.0 % confidence interval :[0.00830,0.01235]
# Problem RP89 Number of function calls = 15591 , Pf = 0.00641 , 95.0 % confidence interval :[0.00516,0.00767]
# Problem RP107 Number of function calls = 10000000 , Pf = 0.00000 , 95.0 % confidence interval :[-0.00000,0.00000]
# Problem RP110 Number of function calls = 2990625 , Pf = 0.00003 , 95.0 % confidence interval :[0.00003,0.00004]
# Problem RP111 Number of function calls = 10000000 , Pf = 0.00000 , 95.0 % confidence interval :[0.00000,0.00000]
# Problem RP63 Number of function calls = 285847 , Pf = 0.00035 , 95.0 % confidence interval :[0.00028,0.00042]
# Problem RP91 Number of function calls = 136151 , Pf = 0.00073 , 95.0 % confidence interval :[0.00059,0.00088]
# Problem RP60 Number of function calls = 1968 , Pf = 0.04878 , 95.0 % confidence interval :[0.03926,0.05830]
# Problem RP77 Number of function calls = 10000000 , Pf = 0.00000 , 95.0 % confidence interval :[-0.00000,0.00000]
# Problem Four-branch serial system (Waarts, 2000) Number of function calls = 43302 , Pf = 0.00231 , 95.0 % confidence interval :[0.00186,0.00276]
# Problem R-S Number of function calls = 1367 , Pf = 0.06876 , 95.0 % confidence interval :[0.05535,0.08218]
# Problem Axial stressed beam Number of function calls = 3812 , Pf = 0.02571 , 95.0 % confidence interval :[0.02068,0.03073]
#                                           Probabilité estimée  \
# RP8                                              7.343168e-04
# RP14                                             6.942998e-04
# RP22                                             3.287851e-03
# RP24                                             2.544853e-03
# RP25                                             4.352436e-05
# RP28                                             2.000000e-07
# RP31                                             3.192644e-03
# RP33                                             2.763347e-03
# RP35                                             2.975748e-03
# RP38                                             8.052827e-03
# RP53                                             3.317373e-02
# RP55                                             5.555556e-01
# RP54                                             1.062496e-03
# RP57                                             2.753582e-02
# RP75                                             1.032648e-02
# RP89                                             6.413957e-03
# RP107                                            2.000000e-07
# RP110                                            3.343783e-05
# RP111                                            5.000000e-07
# RP63                                             3.498375e-04
# RP91                                             7.344786e-04
# RP60                                             4.878049e-02
# RP77                                             2.000000e-07
# Four-branch serial system (Waarts, 2000)         2.309362e-03
# R-S                                              6.876372e-02
# Axial stressed beam                              2.570829e-02
#
#                                           Nombre d'appels à la fonction d'état limite
# RP8                                                                          136181.0
# RP14                                                                         144030.0
# RP22                                                                          30415.0
# RP24                                                                          39295.0
# RP25                                                                        2297564.0
# RP28                                                                       10000000.0
# RP31                                                                          31322.0
# RP33                                                                          36188.0
# RP35                                                                          33605.0
# RP38                                                                          12418.0
# RP53                                                                           2924.0
# RP55                                                                             81.0
# RP54                                                                          94118.0
# RP57                                                                           3559.0
# RP75                                                                           9587.0
# RP89                                                                          15591.0
# RP107                                                                      10000000.0
# RP110                                                                       2990625.0
# RP111                                                                      10000000.0
# RP63                                                                         285847.0
# RP91                                                                         136151.0
# RP60                                                                           1968.0
# RP77                                                                       10000000.0
# Four-branch serial system (Waarts, 2000)                                      43302.0
# R-S                                                                            1367.0
# Axial stressed beam                                                            3812.0

# %%
df.to_csv('exactproba.csv')

# %%
for i in range(26):
    print(List_RP[i].getName(), np.format_float_scientific(results[i][0]))
# Out:
# RP8 7.343168283387579e-04
# RP14 6.942997986530547e-04
# RP22 3.2878513891171977e-03
# RP24 2.54485303473724e-03
# RP25 4.3524358842671254e-05
# RP28 1.9999999999992998e-07
# RP31 3.1926441478832735e-03
# RP33 2.7633469658450384e-03
# RP35 2.9757476565987237e-03
# RP38 8.0528265421163e-03
# RP53 3.317373461012311e-02
# RP55 5.555555555555556e-01
# RP54 1.062496015639941e-03
# RP57 2.753582466985108e-02
# RP75 1.0326483780118904e-02
# RP89 6.413956769931364e-03
# RP107 1.9999999999999501e-07
# RP110 3.343782654126833e-05
# RP111 4.999999999997908e-07
# RP63 3.4983750048102547e-04
# RP91 7.344786303442522e-04
# RP60 4.8780487804878064e-02
# RP77 1.9999999999995084e-07
# Four-branch serial system (Waarts, 2000) 2.309362154173013e-03
# R-S 6.87637161667887e-02
# Axial stressed beam 2.5708289611752384e-02
