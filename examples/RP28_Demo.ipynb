# %% [markdown]
# # RP28 analysis and 2D graphics
#
#
# The objective of this example is to present problem 28 of the BBRC. We also present graphic elements for the visualization of the limit state surface in 2 dimensions.

# %%
import openturns as ot
import numpy as np
import otbenchmark as otb

# %%
problem = otb.ReliabilityProblem28()

# %%
print(problem)
# Out:
# name = RP28
# event = class=ThresholdEventImplementation antecedent=class=CompositeRandomVector function=class=Function name=Unnamed implementation=class=FunctionImplementation name=Unnamed description=[x1,x2,y0] evaluationImplementation=class=SymbolicEvaluation name=Unnamed inputVariablesNames=[x1,x2] outputVariablesNames=[y0] formulas=[ x1 * x2 - 146.14 ] gradientImplementation=class=SymbolicGradient name=Unnamed evaluation=class=SymbolicEvaluation name=Unnamed inputVariablesNames=[x1,x2] outputVariablesNames=[y0] formulas=[ x1 * x2 - 146.14 ] hessianImplementation=class=SymbolicHessian name=Unnamed evaluation=class=SymbolicEvaluation name=Unnamed inputVariablesNames=[x1,x2] outputVariablesNames=[y0] formulas=[ x1 * x2 - 146.14 ] antecedent=class=UsualRandomVector distribution=class=ComposedDistribution name=ComposedDistribution dimension=2 copula=class=IndependentCopula name=IndependentCopula dimension=2 marginal[0]=class=Normal name=Normal dimension=1 mean=class=Point name=Unnamed dimension=1 values=[78064] sigma=class=Point name=Unnamed dimension=1 values=[11710] correlationMatrix=class=CorrelationMatrix dimension=1 implementation=class=MatrixImplementation name=Unnamed rows=1 columns=1 values=[1] marginal[1]=class=Normal name=Normal dimension=1 mean=class=Point name=Unnamed dimension=1 values=[0.0104] sigma=class=Point name=Unnamed dimension=1 values=[0.00156] correlationMatrix=class=CorrelationMatrix dimension=1 implementation=class=MatrixImplementation name=Unnamed rows=1 columns=1 values=[1] operator=class=Less name=Unnamed threshold=0
# probability = 1.46e-07
# description =

# %%
event = problem.getEvent()
g = event.getFunction()

# %%
problem.getProbability()
# Out:
# 1.46e-07

# %%
# Create the Monte-Carlo algorithm
algoProb = ot.ProbabilitySimulationAlgorithm(event)
algoProb.setMaximumOuterSampling(100000)
algoProb.setMaximumCoefficientOfVariation(0.01)
algoProb.run()

# %%
# Get the results
resultAlgo = algoProb.getResult()
neval = g.getEvaluationCallsNumber()
print("Number of function calls = %d" % (neval))
pf = resultAlgo.getProbabilityEstimate()
print("Failure Probability = %.4f" % (pf))
level = 0.95
c95 = resultAlgo.getConfidenceLength(level)
pmin = pf - 0.5 * c95
pmax = pf + 0.5 * c95
print("%.1f %% confidence interval :[%.4f,%.4f] " % (level * 100, pmin, pmax))
# Out:
# Number of function calls = 100000
# Failure Probability = 0.0000
# 95.0 % confidence interval :[0.0000,0.0000]

# %% [markdown]
# ## Compute the bounds of the domain

# %%
inputVector = event.getAntecedent()
distribution = inputVector.getDistribution()
X1 = distribution.getMarginal(0)
X2 = distribution.getMarginal(1)
alphaMin = 0.00001
alphaMax = 1 - alphaMin
lowerBound = ot.Point(
    [X1.computeQuantile(alphaMin)[0], X2.computeQuantile(alphaMin)[0]]
)
upperBound = ot.Point(
    [X1.computeQuantile(alphaMax)[0], X2.computeQuantile(alphaMax)[0]]
)

# %%
nbPoints = [100, 100]
figure = g.draw(lowerBound, upperBound, nbPoints)
figure.setTitle(" Iso-values of limit state function")
figure
# Out:
# class=Graph name=y0 as a function of (x1,x2) implementation=class=GraphImplementation name=y0 as a function of (x1,x2) title= Iso-values of limit state function xTitle=x1 yTitle=x2 axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=y0 as a function of (x1,x2) implementation=class=Contour name=y0 as a function of (x1,x2) x=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=1 data=[[28122.1],[29131.1],[30140],[31148.9],[32157.8],[33166.8],[34175.7],[35184.6],[36193.5],[37202.5],[38211.4],[39220.3],[40229.2],[41238.2],[42247.1],[43256],[44265],[45273.9],[46282.8],[47291.7],[48300.7],[49309.6],[50318.5],[51327.4],[52336.4],[53345.3],[54354.2],[55363.1],[56372.1],[57381],[58389.9],[59398.9],[60407.8],[61416.7],[62425.6],[63434.6],[64443.5],[65452.4],[66461.3],[67470.3],[68479.2],[69488.1],[70497],[71506],[72514.9],[73523.8],[74532.8],[75541.7],[76550.6],[77559.5],[78568.5],[79577.4],[80586.3],[81595.2],[82604.2],[83613.1],[84622],[85631],[86
data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=16641 dimension=1 data=[[7.8358e-09],[9.72333e-09],[1.20246e-08],...,[1.20246e-08],[9.72333e-09],[7.8358e-09]] color=#ff0000 fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=1,class=Drawable name=pdf as a function of (X1,X2) implementation=class=Contour name=pdf as a function of (X1,X2) x=class=Samp ...

# %%
sampleSize = 100000
sampleInput = inputVector.getSample(sampleSize)
sampleOutput = g(sampleInput)
drawEvent = otb.DrawEvent(event)

# %%
cloud = drawEvent.drawSample(sampleInput, sampleOutput)
cloud
# Out:
# class=Graph name=Points X s.t. g(X) < 0.0 implementation=class=GraphImplementation name=Points X s.t. g(X) < 0.0 title=Points X s.t. g(X) < 0.0 xTitle=x1 yTitle=x2 axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=Out implementation=class=Cloud name=Out derived from class=DrawableImplementation name=Out legend=Out data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100000 dimension=2 data=[[82515.4,0.00997651],[66295.9,0.00808216],[74785.1,0.0126568],...,[85190.4,0.0103863],[78980.5,0.0100163],[97750.4,0.0111329]] color=darkseagreen3 fillStyle=solid lineStyle=solid pointStyle=fsquare lineWidth=1]

# %% [markdown]
# ## Draw the limit state surface

# %%
bounds = ot.Interval(lowerBound, upperBound)
bounds
# Out:
# class=Interval name=Unnamed dimension=2 lower bound=class=Point name=Unnamed dimension=2 values=[28122.1,0.00374677] upper bound=class=Point name=Unnamed dimension=2 values=[128006,0.0170532] finite lower bound=[1,1] finite upper bound=[1,1]

# %%
nX = 75
nY = 75
graph = drawEvent.drawLimitState(bounds, nX, nY)
graph.add(cloud)
graph
# Out:
# class=Graph name=Limit state surface implementation=class=GraphImplementation name=Limit state surface title=Limit state surface xTitle=x1 yTitle=x2 axes=ON grid=ON legendposition= legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Contour name=Unnamed x=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=77 dimension=1 description=[t] data=[[28122.1],[29436.4],[30750.6],[32064.9],[33379.2],[34693.4],[36007.7],[37321.9],[38636.2],[39950.5],[41264.7],[42579],[43893.2],[45207.5],[46521.8],[47836],[49150.3],[50464.5],[51778.8],[53093.1],[54407.3],[55721.6],[57035.8],[58350.1],[59664.4],[60978.6],[62292.9],[63607.1],[64921.4],[66235.7],[67549.9],[68864.2],[70178.4],[71492.7],[72807],[74121.2],[75435.5],[76749.7],[78064],[79378.3],[80692.5],[82006.8],[83321],[84635.3],[85949.6],[87263.8],[88578.1],[89892.3],[91206.6],[92520.9],[93835.1],[95149.4],[96463.6],[97777.9],[99092.2],[100406],[101721],[103035],[104349],[105663],[106978],[108292],[109606],[110920],[112235],[113549],[114863],[116178],[117492],[118806],[120120],[121435],[122749],[124063],[125377],[126692],[128006]] y=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=77 dimension=1 description=[t] data=[[0.00374677],[0.00392186],[0.00409694],[0.00427203],[0.00444711],[0.0046222],[0.00479728],[0.00497237],[0.00514745],[0.00532254],[0.00549762],[0.00567271],[0.00584779],[0.00602288],[0.00619796],[0.00637305],[0.00654813],[0.00672322],[0.0068983],[0.00707339],[0.00724847],[0.00742356],[0.00759864],[0.00777373],[0.00794881],[0.0081239],[0.00829898],[0.00847407],[0.00864915],[0.00882424],[0.00899932],[0.00917441],[0.00934949],[0.00952458],[0.00969966],[0.00987475],[0.0100498],[0.0102249],[0.0104],[0.0105751],[0.0107502],[0.0109253],[0.0111003],[0.0112754],[0.0114505],[0.0116256],[0.0118007],[0.0119758],[0.0121508],[0.0123259],[0.012501],[0.0126761],[0.0128512],[0.0130263],[0.0132014],[0.0133764],[0.0135515],[0.0137266],[0.0139017],[0.0140768],[0.0142519],[0.014427],[0.014602],[0.0147771],[0.0149522],[0.0151273],[0.0153024],[0.0154775],[0.0156525],[0.0158276],[0.0160027],[0.0161778],[0.0163529],[0.016528],[0.0167031],[0.0168781],[0.0170532]] levels=class=Point name=Unnamed dimension=1 values=[0] labels=[0.0] show labels=true derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=